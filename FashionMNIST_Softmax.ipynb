# %% [markdown]
# # Fashion-MNIST Classification with a Softmax Head
# This notebook mirrors the LDA-based workflow, but uses a standard softmax classifier head on top of the encoder.

# %% [markdown]
# ### Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
tfm = transforms.ToTensor()
train_ds = datasets.FashionMNIST(root='./data', train=True, transform=tfm, download=True)
test_ds  = datasets.FashionMNIST(root='./data', train=False, transform=tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=2, pin_memory=True)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %% [markdown]
# ### Model: encoder + softmax head

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(1),
        )
        self.proj = nn.Linear(256, dim)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.proj(x)

class SoftmaxHead(nn.Module):
    def __init__(self, D, C):
        super().__init__()
        self.linear = nn.Linear(D, C)

    def forward(self, z):
        return self.linear(z)

class DeepClassifier(nn.Module):
    def __init__(self, C, D):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = SoftmaxHead(D, C)

    def forward(self, x):
        z = self.encoder(x)
        return self.head(z)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot

model = DeepClassifier(C=10, D=9).to(device)
opt = torch.optim.Adam(model.parameters())
loss_fn = nn.CrossEntropyLoss()

for epoch in range(1, 101):
    model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        logits = model(x)
        loss = loss_fn(logits, y)

        opt.zero_grad(set_to_none=True)
        loss.backward()
        opt.step()

        with torch.no_grad():
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)

    tr_acc = acc_sum / n_sum
    te_acc = evaluate(model, test_ld)
    print(f"[{epoch:02d}] train loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}")
# Out:
# [01] train loss=0.5116 acc=0.8304 | test acc=0.8383
# [02] train loss=0.2637 acc=0.9051 | test acc=0.8797
# [03] train loss=0.2183 acc=0.9213 | test acc=0.8924
# [04] train loss=0.1917 acc=0.9306 | test acc=0.8916
# [05] train loss=0.1686 acc=0.9392 | test acc=0.8842
# [06] train loss=0.1499 acc=0.9460 | test acc=0.9068
# [07] train loss=0.1335 acc=0.9523 | test acc=0.9094
# [08] train loss=0.1196 acc=0.9569 | test acc=0.8714
# [09] train loss=0.1034 acc=0.9623 | test acc=0.8870
# [10] train loss=0.0938 acc=0.9667 | test acc=0.8905
# [11] train loss=0.0768 acc=0.9727 | test acc=0.9173
# [12] train loss=0.0646 acc=0.9766 | test acc=0.9059
# [13] train loss=0.0577 acc=0.9786 | test acc=0.9043
# [14] train loss=0.0458 acc=0.9840 | test acc=0.8481
# [15] train loss=0.0410 acc=0.9857 | test acc=0.9047
# [16] train loss=0.0341 acc=0.9878 | test acc=0.8713
# [17] train loss=0.0308 acc=0.9890 | test acc=0.9218
# [18] train loss=0.0280 acc=0.9898 | test acc=0.8723
# [19] train loss=0.0263 acc=0.9907 | test acc=0.9181
# [20] train loss=0.0190 acc=0.9935 | test acc=0.9003
# [21] train loss=0.0179 acc=0.9941 | test acc=0.9244
# [22] train loss=0.0216 acc=0.9921 | test acc=0.9189
# [23] train loss=0.0238 acc=0.9917 | test acc=0.9031
# [24] train loss=0.0174 acc=0.9935 | test acc=0.8929
# [25] train loss=0.0201 acc=0.9926 | test acc=0.8850
# [26] train loss=0.0144 acc=0.9949 | test acc=0.9081
# [27] train loss=0.0129 acc=0.9955 | test acc=0.9251
# [28] train loss=0.0136 acc=0.9951 | test acc=0.9147
# [29] train loss=0.0116 acc=0.9963 | test acc=0.9078
# [30] train loss=0.0181 acc=0.9936 | test acc=0.8721
# [31] train loss=0.0164 acc=0.9942 | test acc=0.9241
# [74] train loss=0.0035 acc=0.9990 | test acc=0.9248
# [75] train loss=0.0047 acc=0.9983 | test acc=0.9272
# [76] train loss=0.0037 acc=0.9988 | test acc=0.9282
# [77] train loss=0.0049 acc=0.9982 | test acc=0.8907
# [78] train loss=0.0070 acc=0.9974 | test acc=0.9061
# [79] train loss=0.0062 acc=0.9978 | test acc=0.9285
# [80] train loss=0.0021 acc=0.9995 | test acc=0.9309
# [81] train loss=0.0002 acc=1.0000 | test acc=0.9313
# [82] train loss=0.0001 acc=1.0000 | test acc=0.9322
# [83] train loss=0.0003 acc=0.9999 | test acc=0.9300
# [84] train loss=0.0001 acc=1.0000 | test acc=0.9319
# [85] train loss=0.0000 acc=1.0000 | test acc=0.9317
# [86] train loss=0.0000 acc=1.0000 | test acc=0.9315
# [87] train loss=0.0000 acc=1.0000 | test acc=0.9327
# [88] train loss=0.0000 acc=1.0000 | test acc=0.9312
# [89] train loss=0.0000 acc=1.0000 | test acc=0.9316
# [90] train loss=0.0000 acc=1.0000 | test acc=0.9322
# [91] train loss=0.0000 acc=1.0000 | test acc=0.9324
# [92] train loss=0.0000 acc=1.0000 | test acc=0.9328
# [93] train loss=0.0000 acc=1.0000 | test acc=0.9324
# [94] train loss=0.0000 acc=1.0000 | test acc=0.9335
# [95] train loss=0.0000 acc=1.0000 | test acc=0.9337
# [96] train loss=0.0000 acc=1.0000 | test acc=0.9330
# [97] train loss=0.0000 acc=1.0000 | test acc=0.9329
# [98] train loss=0.0000 acc=1.0000 | test acc=0.9334
# [99] train loss=0.0000 acc=1.0000 | test acc=0.9323
# [100] train loss=0.0000 acc=1.0000 | test acc=0.9337

# %%
import matplotlib.pyplot as plt

model.eval()
embeds, labels = [], []
with torch.no_grad():
    for i, (x, y) in enumerate(train_ld):   # use train_ld if you prefer
        x = x.to(device)
        z = model.encoder(x).cpu()
        embeds.append(z)
        labels.append(y)
        if i >= 9:   # 10 batches ≈10k points; raise/lower to taste
            break

z = torch.cat(embeds)
y = torch.cat(labels)

# 2D projection (PCA)
z0 = z - z.mean(0, keepdim=True)
U, S, V = torch.pca_lowrank(z0, q=2)
z2 = z0 @ V[:, :2]

plt.rcParams.update({
    "font.size": 14, "axes.labelsize": 16, "legend.fontsize": 13,
    "xtick.labelsize": 13, "ytick.labelsize": 13
})

plt.figure(figsize=(8, 6))
for c in range(10):
    idx = y == c
    plt.scatter(z2[idx, 0], z2[idx, 1], s=8, alpha=0.6, label=train_ds.classes[c])
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.tight_layout()
plt.savefig('plots/fashion_mnist_softmax_embeddings.png', dpi=600)
