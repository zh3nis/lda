# %% [markdown]
# # Fashion-MNIST with a Fisher LDA Head
# This notebook trains a small convolutional encoder with a Fisher-criterion LDA head on Fashion-MNIST, then visualises the learned embedding space.

# %% [markdown]
# ### Setup

# %%
import torch, torch.nn as nn, torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from src.lda import FisherLDAHead

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device =', device)
# Out:
# device = cuda

# %% [markdown]
# ### Data

# %%
tfm = transforms.ToTensor()
train_ds = datasets.FashionMNIST(root='./data', train=True, transform=tfm, download=True)
test_ds  = datasets.FashionMNIST(root='./data', train=False, transform=tfm, download=True)
train_ld = DataLoader(train_ds, batch_size=256, shuffle=True, num_workers=2, pin_memory=True)
test_ld  = DataLoader(test_ds,  batch_size=1024, shuffle=False, num_workers=2, pin_memory=True)
len(train_ds), len(test_ds)
# Out:
# (60000, 10000)

# %% [markdown]
# ### Model: encoder + Fisher LDA head (fixed means, Fisher loss)

# %%
class Encoder(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, 3, padding=1), nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, 3, padding=1), nn.BatchNorm2d(128), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            nn.Conv2d(128, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, 3, padding=1), nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(1),
        )
        self.proj = nn.Linear(256, dim)

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        return self.proj(x)

class DeepFisherLDA(nn.Module):
    def __init__(self, C, D):
        super().__init__()
        self.encoder = Encoder(D)
        self.head = FisherLDAHead(C, D)

    def logits(self, x):
        z = self.encoder(x)
        return self.head.logits(z)

    def forward(self, x, y=None):
        z = self.encoder(x)
        if y is None:
            return self.head.logits(z)
        return self.head(z, y)

# %% [markdown]
# ### Train & Eval

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    ok = tot = 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        logits = model.logits(x)
        ok += (logits.argmax(1) == y).sum().item()
        tot += y.size(0)
    return ok / tot

model = DeepFisherLDA(C=10, D=9).to(device)
opt = torch.optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, 101):
    model.train()
    loss_sum = acc_sum = n_sum = 0
    for x, y in train_ld:
        x, y = x.to(device), y.to(device)
        loss = model(x, y)  # negative Fisher ratio
        opt.zero_grad(set_to_none=True); loss.backward(); opt.step()
        with torch.no_grad():
            logits = model.logits(x)
            pred = logits.argmax(1)
            acc_sum += (pred == y).sum().item()
            n_sum += y.size(0)
            loss_sum += loss.item() * y.size(0)
    tr_acc = acc_sum / n_sum
    te_acc = evaluate(model, test_ld)
    print(f"[{epoch:02d}] fisher_loss={loss_sum/n_sum:.4f} acc={tr_acc:.4f} | test acc={te_acc:.4f}")
# Out:
# [01] fisher_loss=-4.0485 acc=0.8736 | test acc=0.8832
# [02] fisher_loss=-5.7798 acc=0.9255 | test acc=0.9074
# [03] fisher_loss=-6.7789 acc=0.9362 | test acc=0.9190
# [04] fisher_loss=-7.5761 acc=0.9454 | test acc=0.9213
# [05] fisher_loss=-8.4288 acc=0.9531 | test acc=0.9175
# [06] fisher_loss=-9.2303 acc=0.9576 | test acc=0.9255
# [07] fisher_loss=-10.1282 acc=0.9635 | test acc=0.9150
# [08] fisher_loss=-11.0206 acc=0.9682 | test acc=0.9178
# [09] fisher_loss=-12.1670 acc=0.9732 | test acc=0.9285
# [10] fisher_loss=-13.4231 acc=0.9781 | test acc=0.9323
# [11] fisher_loss=-14.9820 acc=0.9823 | test acc=0.9255
# [12] fisher_loss=-16.7486 acc=0.9857 | test acc=0.9359
# [13] fisher_loss=-18.7325 acc=0.9888 | test acc=0.9272
# [14] fisher_loss=-20.9072 acc=0.9912 | test acc=0.9103
# [15] fisher_loss=-23.3266 acc=0.9926 | test acc=0.9345
# [16] fisher_loss=-26.2641 acc=0.9948 | test acc=0.9389
# [17] fisher_loss=-29.9428 acc=0.9960 | test acc=0.9344
# [18] fisher_loss=-34.0759 acc=0.9967 | test acc=0.9326
# [19] fisher_loss=-38.0067 acc=0.9975 | test acc=0.9373
# [20] fisher_loss=-43.1268 acc=0.9981 | test acc=0.9305
# [21] fisher_loss=-46.5051 acc=0.9983 | test acc=0.9324
# [22] fisher_loss=-51.9382 acc=0.9987 | test acc=0.9291
# [23] fisher_loss=-57.4315 acc=0.9989 | test acc=0.9394
# [24] fisher_loss=-63.2663 acc=0.9991 | test acc=0.9372
# [25] fisher_loss=-67.4534 acc=0.9992 | test acc=0.9372
# [26] fisher_loss=-74.4451 acc=0.9994 | test acc=0.9280
# [27] fisher_loss=-82.4242 acc=0.9995 | test acc=0.9370
# [28] fisher_loss=-87.2306 acc=0.9996 | test acc=0.9353
# [29] fisher_loss=-93.0214 acc=0.9997 | test acc=0.9351
# [30] fisher_loss=-97.8074 acc=0.9997 | test acc=0.9355
# [31] fisher_loss=-109.0524 acc=0.9997 | test acc=0.9290
# [32] fisher_loss=-113.0028 acc=0.9997 | test acc=0.9340
# [33] fisher_loss=-125.0969 acc=0.9997 | test acc=0.9320
# [34] fisher_loss=-129.6102 acc=0.9998 | test acc=0.9337
# [35] fisher_loss=-135.6161 acc=0.9997 | test acc=0.9313
# [36] fisher_loss=-141.2008 acc=0.9998 | test acc=0.9338
# [37] fisher_loss=-147.8454 acc=0.9997 | test acc=0.9338
# [38] fisher_loss=-153.2906 acc=0.9998 | test acc=0.9345
# [39] fisher_loss=-167.1396 acc=0.9998 | test acc=0.9323
# [40] fisher_loss=-176.6036 acc=0.9998 | test acc=0.9344
# [41] fisher_loss=-174.7158 acc=0.9999 | test acc=0.9344
# [42] fisher_loss=-189.5328 acc=0.9999 | test acc=0.9342
# [43] fisher_loss=-193.0974 acc=0.9999 | test acc=0.9327
# [44] fisher_loss=-192.1607 acc=0.9999 | test acc=0.9344
# [45] fisher_loss=-205.0276 acc=0.9999 | test acc=0.9330
# [46] fisher_loss=-222.8234 acc=0.9999 | test acc=0.9315
# [47] fisher_loss=-212.1776 acc=0.9999 | test acc=0.9291
# [48] fisher_loss=-228.8278 acc=0.9999 | test acc=0.9315
# [49] fisher_loss=-230.0017 acc=0.9999 | test acc=0.9336
# [50] fisher_loss=-251.7491 acc=0.9999 | test acc=0.9321
# [51] fisher_loss=-270.3740 acc=0.9999 | test acc=0.9327
# [52] fisher_loss=-266.0864 acc=0.9999 | test acc=0.9313
# [53] fisher_loss=-262.1232 acc=0.9999 | test acc=0.9330
# [54] fisher_loss=-272.3368 acc=0.9999 | test acc=0.9283
# [55] fisher_loss=-303.7331 acc=0.9999 | test acc=0.9293
# [56] fisher_loss=-290.8744 acc=0.9999 | test acc=0.9325
# [57] fisher_loss=-301.8434 acc=0.9999 | test acc=0.9295
# [58] fisher_loss=-308.0412 acc=0.9999 | test acc=0.9310
# [59] fisher_loss=-311.4448 acc=0.9999 | test acc=0.9316
# [60] fisher_loss=-335.0141 acc=0.9999 | test acc=0.9338
# [61] fisher_loss=-355.7835 acc=0.9999 | test acc=0.9325
# [62] fisher_loss=-357.7316 acc=0.9999 | test acc=0.9286
# [63] fisher_loss=-365.0125 acc=0.9999 | test acc=0.9305
# [64] fisher_loss=-386.3492 acc=0.9999 | test acc=0.9309
# [65] fisher_loss=-422.7735 acc=0.9999 | test acc=0.9309
# [66] fisher_loss=-434.0333 acc=0.9999 | test acc=0.9289
# [67] fisher_loss=-413.1217 acc=0.9999 | test acc=0.9282
# [68] fisher_loss=-434.7584 acc=0.9999 | test acc=0.9303
# [69] fisher_loss=-401.4084 acc=0.9999 | test acc=0.9281
# [70] fisher_loss=-467.8171 acc=0.9999 | test acc=0.9314
# [71] fisher_loss=-423.2837 acc=0.9999 | test acc=0.9284
# [72] fisher_loss=-443.0547 acc=0.9999 | test acc=0.9261
# [73] fisher_loss=-451.4390 acc=0.9999 | test acc=0.9325
# [74] fisher_loss=-507.8059 acc=0.9999 | test acc=0.9327
# [75] fisher_loss=-501.5060 acc=0.9999 | test acc=0.9313
# [76] fisher_loss=-518.0657 acc=0.9999 | test acc=0.9319
# [77] fisher_loss=-563.7913 acc=0.9999 | test acc=0.9315
# [78] fisher_loss=-600.1912 acc=0.9999 | test acc=0.9283
# [79] fisher_loss=-562.0528 acc=0.9999 | test acc=0.9280
# [80] fisher_loss=-596.6944 acc=0.9999 | test acc=0.9306
# [81] fisher_loss=-637.0339 acc=0.9999 | test acc=0.9307
# [82] fisher_loss=-633.9939 acc=0.9999 | test acc=0.9314
# [83] fisher_loss=-701.0606 acc=0.9999 | test acc=0.9295
# [84] fisher_loss=-652.8681 acc=0.9999 | test acc=0.9310
# [85] fisher_loss=-693.9898 acc=0.9999 | test acc=0.9307
# [86] fisher_loss=-683.6573 acc=0.9999 | test acc=0.9275
# [87] fisher_loss=-735.9714 acc=0.9999 | test acc=0.9262
# [88] fisher_loss=-694.8305 acc=0.9999 | test acc=0.9288
# [89] fisher_loss=-707.8646 acc=0.9999 | test acc=0.9259
# [90] fisher_loss=-729.8786 acc=0.9999 | test acc=0.9291
# [91] fisher_loss=-713.8721 acc=0.9999 | test acc=0.9313
# [92] fisher_loss=-762.5809 acc=0.9999 | test acc=0.9302
# [93] fisher_loss=-814.5926 acc=0.9999 | test acc=0.9294
# [94] fisher_loss=-830.0387 acc=0.9999 | test acc=0.9298
# [95] fisher_loss=-861.6639 acc=0.9999 | test acc=0.9271
# [96] fisher_loss=-841.5682 acc=0.9999 | test acc=0.9301
# [97] fisher_loss=-840.5125 acc=0.9999 | test acc=0.9265
# [98] fisher_loss=-883.2805 acc=0.9999 | test acc=0.9257
# [99] fisher_loss=-901.1409 acc=0.9999 | test acc=0.9267
# [100] fisher_loss=-912.8783 acc=0.9999 | test acc=0.9292

# %%
import matplotlib.pyplot as plt

model.eval()
embeds, labels = [], []
with torch.no_grad():
    for i, (x, y) in enumerate(train_ld):   # use train_ld if you prefer
        x = x.to(device)
        z = model.encoder(x).cpu()
        embeds.append(z)
        labels.append(y)
        if i >= 9:   # 10 batches ≈10k points; raise/lower to taste
            break

z = torch.cat(embeds)
y = torch.cat(labels)

# 2D projection (PCA)
z0 = z - z.mean(0, keepdim=True)
U, S, V = torch.pca_lowrank(z0, q=2)
z2 = z0 @ V[:, :2]

plt.rcParams.update({
    "font.size": 14, "axes.labelsize": 16, "legend.fontsize": 13,
    "xtick.labelsize": 13, "ytick.labelsize": 13
})

plt.figure(figsize=(8, 6))
for c in range(10):
    idx = y == c
    plt.scatter(z2[idx, 0], z2[idx, 1], s=8, alpha=0.6, label=train_ds.classes[c])
plt.legend(bbox_to_anchor=(1.02, 1), loc="upper left")
plt.xlabel("PC1"); plt.ylabel("PC2")
plt.tight_layout()
plt.savefig('plots/fashion_mnist_fisher_embeddings.png', dpi=600)
